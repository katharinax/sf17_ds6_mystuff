# %%
import numpy as np
import pandas as pd
import copy
import operator
import matplotlib.pyplot as plt
import seaborn as sns
import re
import pickle
import sys
from sklearn.preprocessing import Imputer
# %matplotlib inline  
pd.set_option('display.max_columns', 400)

# %%
def str_to_num_helper(text):
    try:
        num = float(re.sub(r"[^0-9.]", r"", text))
    except:
        num = np.nan
    return num

# %%
def str_to_num(df, varname):
    
    return(df[varname].map(lambda x: str_to_num_helper(x)))

# %%
def get_agg (df, yr, col_for_agg):
    """
    limitation: works on my data with specific cols
    output: one row of aggregated statistics as pandas DataFrame
    """
    if yr:
        agg_df = pd.DataFrame(df.loc[df['yr_diff'] <= yr, col_for_agg].mean())
    else:
        agg_df = pd.DataFrame(df.loc[:, col_for_agg].mean())
    agg_df = agg_df.reset_index()
    agg_df = agg_df.pivot(index = [0] * 5, columns='index', values=0)
    if yr:
        agg_df.columns = agg_df.columns + "_" + str(yr) + "yr" 
    else:
        agg_df.columns = agg_df.columns + "_allyr"
    return agg_df

# %%
def get_player_history (plr_df, movieid, role, playerid):
    if pd.isnull(playerid):
        return None
    else:
        d_cond = plr_df['movieid'] == movieid
        max_date = plr_df.loc[d_cond, 'release_date'].iloc[0]
        ap_cond = (plr_df['role'] == role) & (plr_df['playerid'] == playerid) & (plr_df['release_date'] < max_date)
        plr_cols = ['movieid', 'log_life_gross', 'life_theater', 'log_open_gross', 'open_theater', 'release_date', \
                    'release_yr', 'release_mon', 'release_wday_num', 'rank_num']
        df = plr_df.loc[ap_cond, plr_cols]
        df = df.sort_values(by = 'release_date', ascending = False)

        df['yr_diff'] = ((max_date - df['release_date']).dt.days / 365).map(np.ceil)
        col_for_agg = ['log_life_gross', 'life_theater', 'log_open_gross', 'open_theater', 'rank_num']
        plr_stats = get_agg(df, 1, col_for_agg)
        plr_stats = plr_stats.merge(get_agg(df, 3, col_for_agg), left_index = True, right_index=True)
        plr_stats = plr_stats.merge(get_agg(df, 5, col_for_agg), left_index = True, right_index=True)
        plr_stats = plr_stats.merge(get_agg(df, None, col_for_agg), left_index = True, right_index=True)

        plr_stats.loc[:, 'movieid'] = movieid
        plr_stats.loc[:, 'role'] = role
        plr_stats.loc[:, 'playerid'] = playerid
        return plr_stats

# %% [markdown]
# # import data

# %%
with open("my_data.pkl", 'rb') as picklefile: 
    gross_df = pickle.load(picklefile).drop_duplicates()
    meta_df = pickle.load(picklefile).drop_duplicates()
    movie_main = pickle.load(picklefile).drop_duplicates()
    player_gross_df = pickle.load(picklefile).drop_duplicates()
    player_meta_df = pickle.load(picklefile).drop_duplicates()
    players_df = pickle.load(picklefile).drop_duplicates()

# %% [markdown]
# # cleaning

# %%
#TODO use only training for studio ranking
#save training mean/min/.. to impute testing

# %%
#clean player_gross_df
player_gross_df['plr_life_mv_num'] = str_to_num(player_gross_df, 'plr_life_mv_num')
player_gross_df['plr_log_life_gross'] = str_to_num(player_gross_df, 'plr_life_gross').map(np.log)
player_gross_df['plr_log_avg_gross'] = str_to_num(player_gross_df, 'plr_avg_gross').map(np.log)
player_gross_df['plr_open_mv_num'] = str_to_num(player_gross_df, 'plr_open_mv_num')
player_gross_df['plr_log_avg_open_gross'] = str_to_num(player_gross_df, 'plr_avg_open_gross').map(np.log)
del player_gross_df['plr_life_gross'], player_gross_df['plr_avg_gross'], player_gross_df['plr_avg_open_gross']

# %%
#clean player_meta_df
cond_na = player_meta_df['release_date'] == 'N/A'
player_meta_df.loc[cond_na, 'release_date_num'] = np.nan
player_meta_df.loc[~cond_na, 'release_date_num'] = pd.to_datetime(player_meta_df.loc[~cond_na, 'release_date'])
del player_meta_df['release_date']
player_meta_df = player_meta_df.rename(index = str, columns = {'release_date_num': 'release_date'})
player_meta_df['release_yr'] = player_meta_df['release_date'].dt.year
player_meta_df['release_mon'] = player_meta_df['release_date'].dt.month
player_meta_df['release_wday_num'] = player_meta_df['release_date'].map(lambda x: x.isoweekday())

player_meta_df['log_life_gross'] = str_to_num(player_meta_df, 'life_gross').map(np.log)
player_meta_df['life_theater'] = str_to_num(player_meta_df, 'life_theater')
player_meta_df['log_open_gross'] = str_to_num(player_meta_df, 'open_gross').map(np.log)
player_meta_df['open_theater'] = str_to_num(player_meta_df, 'open_theater')
del player_meta_df['life_gross'], player_meta_df['open_gross']

cond = player_meta_df['Rank'] != '-'
player_meta_df.loc[cond, 'rank_num'] = pd.to_numeric(player_meta_df.loc[cond,'Rank'])
del player_meta_df['Rank']

# %%
#clean movie_main
cond = movie_main['Rank'] != '-'
movie_main.loc[cond, 'rank_num'] = pd.to_numeric(movie_main.loc[cond,'Rank'])
del movie_main['Rank']

movie_main['life_theater'] = str_to_num(movie_main, 'life_theater')
movie_main['open_theater'] = str_to_num(movie_main, 'open_theater')

movie_main['log_life_gross'] = str_to_num(movie_main, 'life_gross').map(np.log)
movie_main['log_open_gross'] = str_to_num(movie_main, 'open_gross').map(np.log)
del movie_main['life_gross'], movie_main['open_gross']

movie_main['release_date'] = pd.to_datetime(movie_main['release_date'])
movie_main['release_yr'] = movie_main['release_date'].dt.year
movie_main['release_wday_num'] = movie_main['release_date'].map(lambda x: x.isoweekday())

movie_main['release_mon'] = movie_main['release_date'].dt.month
movie_main['release_mon2'] = movie_main['release_mon'].map(lambda x: x ** 2)
movie_main['release_mon3'] = movie_main['release_mon'].map(lambda x: x ** 3)

movie_main.loc[:, 'genre_sd'] = movie_main['genre'] == 'summerdrama'
movie_main.loc[:, 'genre_cm'] = movie_main['genre'] == 'crime'
movie_main.loc[:, 'genre_r'] = movie_main['genre'] == 'r-ratedcomedy'
movie_main.loc[:, 'genre_cp'] = movie_main['genre'] == 'caper'
#del movie_main['genre']

# %%
#clean gross_df
gross_df['log_life_frn_gross'] = str_to_num(gross_df, 'life_frn_gross').map(np.log)
gross_df['log_avg_open_gross'] = str_to_num(gross_df, 'avg_open_gross').map(np.log)
gross_df['pct_open_gross'] = gross_df['pct_open_gross'].map(float)
del gross_df['life_frn_gross'], gross_df['avg_open_gross']

# %%
gross_df.head()
# Out:
#   life_frn_gross avg_open_gross       pct_open_gross            movieid
# 0    347,693,217        15,329   0.07400000000000001        forrestgump
# 1    265,300,000        12,414                 0.141  savingprivateryan
# 2    250,678,391        18,381                 0.298        pearlharbor
# 3    269,935,000        11,851                 0.185          gladiator
# 4    146,100,000        12,129                 0.226       perfectstorm

# %%
#clean meta_df
meta_df.loc[:, 'mpaa_pg13'] = meta_df['mpaa'] == 'PG-13'
meta_df.loc[:, 'mpaa_pg'] = meta_df['mpaa'] == 'PG'
cond = meta_df['mpaa'] == 'Unrated'
meta_df.loc[cond, ['mpaa_pg13', 'mpaa_pg']] = np.nan 
del meta_df['mpaa']

pattern = r"(?P<hr>[0-9]+?) hrs. (?P<min>[0-9]+?) min"
mv_hr, mv_min = list(zip(*meta_df['runtime'].map(lambda x: re.search(pattern, x).groups())))
meta_df['runtime_mins'] = np.array([int(x) * 60 for x in mv_hr]) + np.array([int(x) for x in mv_min])
del meta_df['runtime']

million = meta_df['budget'].map(lambda x: bool(re.match(r" *[0-9.]* *million *", x)))
meta_df.loc[million, 'budget_num'] = meta_df.loc[million, 'budget'].map(lambda x: float(re.sub(r"[^0-9.]", r"", x)) * 10 ** 6)
meta_df.loc[~million, 'budget_num'] = meta_df.loc[~million, 'budget'].map(lambda x: float(re.sub(r"[^0-9.]", r"", x)))
meta_df['log_budget_num'] = meta_df['budget_num'].map(np.log)
del meta_df['budget'], meta_df['budget_num']

# %%
#get movie df - one row per movie
movie = movie_main.merge(meta_df, how = 'left', on = 'movieid')
movie = movie.merge(gross_df, how = 'left', on = 'movieid')

# %%
movie['ww_log_life_gross'] = (movie['log_life_gross'].map(np.exp) + movie['log_life_frn_gross'].map(np.exp)).map(np.log)
movie['pct_life_gross'] = movie['log_life_gross'].map(np.exp) / movie['ww_log_life_gross'].map(np.exp)

# %%
movie['n_miss_mv_cols'] = movie.isnull().sum(axis=1)

# %%
#get movie-player df - one row per movie-role-player
movie_player = movie.merge(players_df, how = 'left', on = 'movieid')
movie_player = movie_player.merge(player_gross_df, how = 'left', on = ['role', 'playerid'])

# %%
#get a set b/c same movie can be listed under multiple genres
plr_set = movie_player.loc[:, ['movieid', 'role', 'playerid']].drop_duplicates()
plr_set = plr_set.reset_index(drop = True)

# %%
#get player history 
wide = pd.DataFrame()
for i in range(plr_set.shape[0]):
    one_row = plr_set.iloc[i]
    wide = wide.append(get_player_history(player_meta_df, one_row['movieid'], one_row['role'], one_row['playerid']))
wide = wide.reset_index(drop = True)

# %%
movie_player = movie_player.merge(wide, how = 'left', on = ['movieid', 'role', 'playerid'])

# %%
movie_player['log_life_gross_diff31'] = movie_player['log_life_gross_3yr'] - movie_player['log_life_gross_1yr']
movie_player['log_open_gross_diff31'] = movie_player['log_open_gross_3yr'] - movie_player['log_open_gross_1yr']

movie_player['log_life_gross_diff53'] = movie_player['log_life_gross_5yr'] - movie_player['log_life_gross_3yr']
movie_player['log_open_gross_diff53'] = movie_player['log_open_gross_5yr'] - movie_player['log_open_gross_3yr']

# %%
#rank studio
rank_stu = player_meta_df[player_meta_df['Studio'] != 'N/A']
rank_stu = pd.DataFrame(player_meta_df['Studio'].value_counts())
rank_stu['rank_stu'] = rank_stu.rank(axis = 0, method = 'dense')
rank_stu['rank_stu2'] = rank_stu['rank_stu'].map(lambda x: x ** 2)
rank_stu['rank_stu3'] = rank_stu['rank_stu'].map(lambda x: x ** 3)
rank_stu.reset_index(inplace = True)
rank_stu = rank_stu.rename(index = str, columns = {'Studio': 'studio_mv_ct', 'index': 'Studio'})

# %%
movie_player = movie_player.merge(rank_stu, how = "left", on = 'Studio')
#del movie_player['Studio']

# %%
#player rank
ct = pd.DataFrame(players_df.groupby(['movieid', 'role']).cumcount())
rank_plr = players_df.merge(ct, left_index = True, right_index = True)
rank_plr = rank_plr.rename(index = str, columns = {0: 'rank_plr'})

# %%
#filter out lower ranked players
movie_filtered = movie_player.merge(rank_plr, how = 'left', on = ['movieid', 'role', 'playerid', 'player'])
kickout = ((movie_filtered['role'].isin(['Producer', 'Director', 'Writer'])) & (movie_filtered['rank_plr'] > 0)) | \
          ((movie_filtered['role'] == 'Actor') & (movie_filtered['rank_plr'] > 1))    
movie_filtered = movie_filtered.loc[~kickout]
movie_filtered.loc[:, 'rank_plr_ch'] = movie_filtered['rank_plr'].astype(str)

# %% [markdown]
# # missing data

# %%
#systematic missing: more missing in lowest ranked movies

# %%
#TODO should I fill na and rank variables on only training data?

# %%
for col in ['log_life_gross', 'life_theater', 'log_open_gross', 'open_theater', 'log_budget_num', 'log_life_frn_gross', \
           'log_avg_open_gross', 'ww_log_life_gross', 'plr_life_mv_num', 'plr_log_life_gross', 'plr_log_avg_gross', \
           'plr_open_mv_num', 'plr_log_avg_open_gross',
           'log_life_gross_1yr', 'life_theater_1yr', 'log_open_gross_1yr', 'open_theater_1yr', \
            'log_life_gross_3yr', 'life_theater_3yr', 'log_open_gross_3yr', 'open_theater_3yr', \
            'log_life_gross_5yr', 'life_theater_5yr', 'log_open_gross_5yr', 'open_theater_5yr', \
            'log_life_gross_allyr', 'life_theater_allyr', 'log_open_gross_allyr', 'open_theater_allyr']:
    movie_filtered.loc[:, col] = movie_filtered.groupby('genre').transform(lambda x: x.fillna(x.min())).loc[:, col]

# %%
for col in ['rank_num', 'rank_num_1yr', 'rank_num_3yr','rank_num_5yr', 'rank_num_allyr']:
    movie_filtered.loc[:, col] = movie_filtered.groupby('genre').transform(lambda x: x.fillna(x.max())).loc[:, col]

# %%
for col in ['mpaa_pg13', 'mpaa_pg']:
    movie_filtered.loc[:, col] = movie_filtered.groupby('genre').transform(lambda x: x.fillna(False)).loc[:, col]

# %%
for col in ['runtime_mins', 'pct_open_gross', 'pct_life_gross', 'log_life_gross_diff31', 'log_open_gross_diff31', \
           'log_life_gross_diff53', 'log_open_gross_diff53']:
    movie_filtered.loc[:, col] = movie_filtered.groupby('genre').transform(lambda x: x.fillna(np.nanmedian(x))).loc[:, col]

# %%
for col in ['studio_mv_ct', 'rank_stu', 'rank_stu2', 'rank_stu3']:
    movie_filtered.loc[:, col] = movie_filtered.groupby('genre').transform(lambda x: x.fillna(1)).loc[:, col]

# %% [markdown]
# # final data

# %%
by_cols = ['movieid', 'log_life_gross', 'life_theater', 'log_open_gross', 'open_theater', 'n_miss_mv_cols', \
           'rank_num', 'release_yr', 'release_mon', 'release_mon2', 'release_mon3', 'release_wday_num', \
           'genre_sd', 'genre_cm', 'genre_r', 'genre_cp', 'mpaa_pg13', 'mpaa_pg', 'runtime_mins', \
           'log_budget_num', 'log_life_frn_gross', 'log_avg_open_gross', 'pct_open_gross', 'ww_log_life_gross', \
           'pct_life_gross', 'studio_mv_ct', 'rank_stu', 'rank_stu2', 'rank_stu3'] 
transpose_cols = ['role', 'rank_plr_ch']
val_cols = ['plr_life_mv_num', 'plr_log_life_gross', 'plr_log_avg_gross', 'plr_open_mv_num', 'plr_log_avg_open_gross', \
            'log_life_gross_1yr', 'life_theater_1yr', 'log_open_gross_1yr', 'open_theater_1yr', 'rank_num_1yr', \
            'log_life_gross_3yr', 'life_theater_3yr', 'log_open_gross_3yr', 'open_theater_3yr', 'rank_num_3yr', \
            'log_life_gross_5yr', 'life_theater_5yr', 'log_open_gross_5yr', 'open_theater_5yr', 'rank_num_5yr', \
            'log_life_gross_allyr', 'life_theater_allyr', 'log_open_gross_allyr', 'open_theater_allyr', \
            'rank_num_allyr', 'log_life_gross_diff31', 'log_open_gross_diff31', 'log_life_gross_diff53', \
            'log_open_gross_diff53'] 
keep = (movie_filtered['role'].isin(['Producer', 'Director', 'Writer', 'Actor'])) 
mv_piv = pd.pivot_table(movie_filtered.loc[keep], index = 'movieid', columns = transpose_cols, values = val_cols)
mv_piv.reset_index(inplace = True)
mv_piv.columns = ['_'.join(x).strip('_') for x in mv_piv.columns.values]

# %%
movie_wide = movie_filtered.loc[:, by_cols].drop_duplicates().merge(mv_piv, how = 'left', on = 'movieid')

# %%
plr_ct = pd.DataFrame(movie_player.groupby('movieid').count()['role'])
plr_ct.reset_index(inplace = True)
plr_ct = plr_ct.rename(index = str, columns = {'role': 'n_plrs'})
movie_wide = movie_wide.merge(plr_ct, how = "left", on = 'movieid')

# %%
#TODO refine final fillna
num_cols = movie_wide.dtypes.astype(str).isin(['float64', 'int64'])
movie_wide.loc[:, num_cols] = movie_wide.loc[:, num_cols].apply(lambda x: x.fillna(np.nanmedian(x)), axis = 0)

bool_cols = movie_wide.dtypes.astype(str).isin(['bool'])
movie_wide.loc[:, bool_cols] = movie_wide.loc[:, bool_cols].apply(lambda x: x.fillna(False), axis = 0)

# %%
movie_wide.set_index('movieid', inplace = True)
movie_wide.index.name = None

# %% [markdown]
# # exploratory

# %%
movie_wide.shape
# Out:
# (644, 290)

# %%
movie_wide.tail(1)
# Out:
#               log_life_gross  life_theater  log_open_gross  open_theater  \
# extrememovie       10.185315           3.0        9.367686           3.0
#
#               n_miss_mv_cols  rank_num  release_yr  release_mon  release_mon2  \
# extrememovie              12     115.0        2008           12           144
#
#               release_mon3  release_wday_num genre_sd genre_cm genre_r  \
# extrememovie          1728                 5    False    False    True
#
#              genre_cp  mpaa_pg13  mpaa_pg  runtime_mins  log_budget_num  \
# extrememovie    False        0.0      0.0          98.0       10.203592
#
#               log_life_frn_gross  log_avg_open_gross  pct_open_gross  \
# extrememovie           10.785373            6.669498           0.314
#
#               ww_log_life_gross  pct_life_gross  studio_mv_ct  rank_stu  \
# extrememovie          11.331871         0.64305          85.0      45.0
#
#               rank_stu2  rank_stu3  plr_life_mv_num_Actor_0.0  \
# extrememovie     2025.0    91125.0                       32.0
#
#               plr_life_mv_num_Actor_1.0  plr_life_mv_num_Director_0.0  \
# extrememovie                       28.0                           7.0
#
#               plr_life_mv_num_Producer_0.0  plr_life_mv_num_Writer_0.0  \
# extrememovie                          22.0                         5.0
#
#               plr_log_life_gross_Actor_0.0  plr_log_life_gross_Actor_1.0  \
# extrememovie                     21.091861                     20.870165
#
#               plr_log_life_gross_Director_0.0  \
# extrememovie                        19.401794
#
#               plr_log_life_gross_Producer_0.0  plr_log_life_gross_Writer_0.0  \
# extrememovie                        20.643776                       19.28126
#
#               plr_log_avg_gross_Actor_0.0  plr_log_avg_gross_Actor_1.0  \
# extrememovie                     17.66091                    17.657195
#
#               plr_log_avg_gross_Director_0.0  plr_log_avg_gross_Producer_0.0  \
# extrememovie                       17.508741                       17.689146
#
#               plr_log_avg_gross_Writer_0.0  plr_open_mv_num_Actor_0.0  \
# extrememovie                      17.70327                       17.0
#
#               plr_open_mv_num_Actor_1.0  plr_open_mv_num_Director_0.0  \
# extrememovie                       16.0                           4.0
#
#               plr_open_mv_num_Producer_0.0  plr_open_mv_num_Writer_0.0  \
# extrememovie                          15.0                         4.0
#
#               plr_log_avg_open_gross_Actor_0.0  \
# extrememovie                         16.796568
#
#               plr_log_avg_open_gross_Actor_1.0  \
# extrememovie                         16.828274
#
#               plr_log_avg_open_gross_Director_0.0  \
# extrememovie                            16.477976
#
#               plr_log_avg_open_gross_Producer_0.0  \
# extrememovie                            16.566477
#
#               plr_log_avg_open_gross_Writer_0.0  log_life_gross_1yr_Actor_0.0  \
# extrememovie                          16.602757                     14.960897
#
#               log_life_gross_1yr_Actor_1.0  log_life_gross_1yr_Director_0.0  \
# extrememovie                     15.244072                         8.757941
#
#               log_life_gross_1yr_Producer_0.0  log_life_gross_1yr_Writer_0.0  \
# extrememovie                        14.451523                       8.757941
#
#               life_theater_1yr_Actor_0.0  life_theater_1yr_Actor_1.0  \
# extrememovie                       892.0                  944.333333
#
#               life_theater_1yr_Director_0.0  life_theater_1yr_Producer_0.0  \
# extrememovie                            2.0                          213.5
#
#               life_theater_1yr_Writer_0.0  log_open_gross_1yr_Actor_0.0  \
# extrememovie                          2.0                     13.034046
#
#               log_open_gross_1yr_Actor_1.0  log_open_gross_1yr_Director_0.0  \
# extrememovie                     12.872237                         7.911691
#
#               log_open_gross_1yr_Producer_0.0  log_open_gross_1yr_Writer_0.0  \
# extrememovie                        11.464229                       7.911691
#
#               open_theater_1yr_Actor_0.0  open_theater_1yr_Actor_1.0  \
# extrememovie                       630.5                       482.0
#
#               open_theater_1yr_Director_0.0  open_theater_1yr_Producer_0.0  \
# extrememovie                            1.0                            8.0
#
#               open_theater_1yr_Writer_0.0  rank_num_1yr_Actor_0.0  \
# extrememovie                          1.5                    28.0
#
#               rank_num_1yr_Actor_1.0  rank_num_1yr_Director_0.0  \
# extrememovie                    21.5                      94.75
#
#               rank_num_1yr_Producer_0.0  rank_num_1yr_Writer_0.0  \
# extrememovie                       37.0                    94.75
#
#               log_life_gross_3yr_Actor_0.0  log_life_gross_3yr_Actor_1.0  \
# extrememovie                      16.53229                     16.230101
#
#               log_life_gross_3yr_Director_0.0  \
# extrememovie                        13.315435
#
#               log_life_gross_3yr_Producer_0.0  log_life_gross_3yr_Writer_0.0  \
# extrememovie                        16.653454                      10.346024
#
#               life_theater_3yr_Actor_0.0  life_theater_3yr_Actor_1.0  \
# extrememovie                      1690.0                 1630.285714
#
#               life_theater_3yr_Director_0.0  life_theater_3yr_Producer_0.0  \
# extrememovie                           53.0                         1762.0
#
#               life_theater_3yr_Writer_0.0  log_open_gross_3yr_Actor_0.0  \
# extrememovie                          5.0                     14.788786
#
#               log_open_gross_3yr_Actor_1.0  log_open_gross_3yr_Director_0.0  \
# extrememovie                      14.55493                        10.810804
#
#               log_open_gross_3yr_Producer_0.0  log_open_gross_3yr_Writer_0.0  \
# extrememovie                        14.744682                       9.225973
#
#               open_theater_3yr_Actor_0.0  open_theater_3yr_Actor_1.0  \
# extrememovie                      1441.4                      1504.0
#
#               open_theater_3yr_Director_0.0  open_theater_3yr_Producer_0.0  \
# extrememovie                            6.0                         1584.0
#
#               open_theater_3yr_Writer_0.0  rank_num_3yr_Actor_0.0  \
# extrememovie                          2.0                    16.0
#
#               rank_num_3yr_Actor_1.0  rank_num_3yr_Director_0.0  \
# extrememovie                  15.625                       14.0
#
#               rank_num_3yr_Producer_0.0  rank_num_3yr_Writer_0.0  \
# extrememovie                       15.0                69.666667
#
#               log_life_gross_5yr_Actor_0.0  log_life_gross_5yr_Actor_1.0  \
# extrememovie                     16.522906                     16.190022
#
#               log_life_gross_5yr_Director_0.0  \
# extrememovie                        15.745489
#
#               log_life_gross_5yr_Producer_0.0  log_life_gross_5yr_Writer_0.0  \
# extrememovie                        16.822288                      15.571819
#
#               life_theater_5yr_Actor_0.0  life_theater_5yr_Actor_1.0  \
# extrememovie                      1706.0                    1534.125
#
#               life_theater_5yr_Director_0.0  life_theater_5yr_Producer_0.0  \
# extrememovie                          827.0                        1797.25
#
#               life_theater_5yr_Writer_0.0  log_open_gross_5yr_Actor_0.0  \
# extrememovie                        864.0                     14.795846
#
#               log_open_gross_5yr_Actor_1.0  log_open_gross_5yr_Director_0.0  \
# extrememovie                     14.379133                        12.830743
#
#               log_open_gross_5yr_Producer_0.0  log_open_gross_5yr_Writer_0.0  \
# extrememovie                        15.011725                      12.400931
#
#               open_theater_5yr_Actor_0.0  open_theater_5yr_Actor_1.0  \
# extrememovie                 1512.666667                      1341.5
#
#               open_theater_5yr_Director_0.0  open_theater_5yr_Producer_0.0  \
# extrememovie                          350.0                         1622.6
#
#               open_theater_5yr_Writer_0.0  rank_num_5yr_Actor_0.0  \
# extrememovie                         32.0               15.571429
#
#               rank_num_5yr_Actor_1.0  rank_num_5yr_Director_0.0  \
# extrememovie                    15.6                        7.5
#
#               rank_num_5yr_Producer_0.0  rank_num_5yr_Writer_0.0  \
# extrememovie                       13.1                      7.0
#
#               log_life_gross_allyr_Actor_0.0  log_life_gross_allyr_Actor_1.0  \
# extrememovie                       16.371728                       16.027957
#
#               log_life_gross_allyr_Director_0.0  \
# extrememovie                          16.152218
#
#               log_life_gross_allyr_Producer_0.0  \
# extrememovie                          16.598927
#
#               log_life_gross_allyr_Writer_0.0  life_theater_allyr_Actor_0.0  \
# extrememovie                        15.938379                   1388.117647
#
#               life_theater_allyr_Actor_1.0  life_theater_allyr_Director_0.0  \
# extrememovie                        1369.9                       983.485294
#
#               life_theater_allyr_Producer_0.0  life_theater_allyr_Writer_0.0  \
# extrememovie                      1575.333333                    1028.833333
#
#               log_open_gross_allyr_Actor_0.0  log_open_gross_allyr_Actor_1.0  \
# extrememovie                       14.478194                       14.118339
#
#               log_open_gross_allyr_Director_0.0  \
# extrememovie                          13.513995
#
#               log_open_gross_allyr_Producer_0.0  \
# extrememovie                          14.799596
#
#               log_open_gross_allyr_Writer_0.0  open_theater_allyr_Actor_0.0  \
# extrememovie                         13.36669                       1229.04
#
#               open_theater_allyr_Actor_1.0  open_theater_allyr_Director_0.0  \
# extrememovie                       1183.75                       658.068182
#
#               open_theater_allyr_Producer_0.0  open_theater_allyr_Writer_0.0  \
# extrememovie                      1373.594203                     667.842105
#
#               rank_num_allyr_Actor_0.0  rank_num_allyr_Actor_1.0  \
# extrememovie                 18.555556                 16.888889
#
#               rank_num_allyr_Director_0.0  rank_num_allyr_Producer_0.0  \
# extrememovie                          6.0                    13.913043
#
#               rank_num_allyr_Writer_0.0  log_life_gross_diff31_Actor_0.0  \
# extrememovie                        6.0                              0.0
#
#               log_life_gross_diff31_Actor_1.0  \
# extrememovie                              0.0
#
#               log_life_gross_diff31_Director_0.0  \
# extrememovie                                 0.0
#
#               log_life_gross_diff31_Producer_0.0  \
# extrememovie                                 0.0
#
#               log_life_gross_diff31_Writer_0.0  \
# extrememovie                               0.0
#
#               log_open_gross_diff31_Actor_0.0  \
# extrememovie                              0.0
#
#               log_open_gross_diff31_Actor_1.0  \
# extrememovie                              0.0
#
#               log_open_gross_diff31_Director_0.0  \
# extrememovie                                 0.0
#
#               log_open_gross_diff31_Producer_0.0  \
# extrememovie                                 0.0
#
#               log_open_gross_diff31_Writer_0.0  \
# extrememovie                               0.0
#
#               log_life_gross_diff53_Actor_0.0  \
# extrememovie                              0.0
#
#               log_life_gross_diff53_Actor_1.0  \
# extrememovie                              0.0
#
#               log_life_gross_diff53_Director_0.0  \
# extrememovie                                 0.0
#
#               log_life_gross_diff53_Producer_0.0  \
# extrememovie                                 0.0
#
#               log_life_gross_diff53_Writer_0.0  \
# extrememovie                               0.0
#
#               log_open_gross_diff53_Actor_0.0  \
# extrememovie                              0.0
#
#               log_open_gross_diff53_Actor_1.0  \
# extrememovie                              0.0
#
#               log_open_gross_diff53_Director_0.0  \
# extrememovie                                 0.0
#
#               log_open_gross_diff53_Producer_0.0  \
# extrememovie                                 0.0
#
#               log_open_gross_diff53_Writer_0.0  n_plrs
# extrememovie                               0.0       0

# %%
movie.columns

# %%
movie.groupby('Studio').boxplot('life_gross')

# %%
movie.groupby('life_gross').boxplot('life_gross')

# %%
rank_stu.head()
# Out:
#   Studio  studio_mv_ct  rank_stu  rank_stu2  rank_stu3
# 0     WB          3190      86.0     7396.0   636056.0
# 1   Uni.          2600      85.0     7225.0   614125.0
# 2    Fox          2116      84.0     7056.0   592704.0
# 3     BV          1992      83.0     6889.0   571787.0
# 4   Par.          1929      82.0     6724.0   551368.0

# %%
rank_stu.hist('studio_mv_ct', bins = 100)
plt.ylim((0, 20))
# Out:
# (0, 20)

# %%
#movie.info()

# %%
#player.info()

# %%
#TODO add features: , n_miss_plr_cols

# %%
player[player['release_date'].isnull()] +

# %%
movie_player.loc[pd.isnull(movie_player['role'])]
# Out:
#                           movieid                               Title  \
# 337                   mebeforeyou                       Me Before You
# 640   jojodanceryourlifeiscalling  Jo Jo Dancer, Your Life is Calling
# 770                           tex                                 Tex
# 825                wherehopegrows                    Where Hope Grows
# 828             faithofourfathers                Faith of Our Fathers
# 833                  hungryhearts                       Hungry Hearts
# 844                      exorcist                        The Exorcist
# 852             blairwitchproject             The Blair Witch Project
# 911              amityvillehorror               The Amityville Horror
# 1267                        rings                               Rings
# 1280                       forest                          The Forest
# 1328                          fog                             The Fog
# 1347                    believers                       The Believers
# 1370                 poltergeist3                     Poltergeist III
# 1372                         gate                            The Gate
# 1380                  amityville2       Amityville II: The Possession
# 1396                   witchboard                          Witchboard
# 1416                        gate2                             Gate II
# 1417                 vaticantapes                   The Vatican Tapes
# 1418                    abandoned                       The Abandoned
# 1419                     babadook                        The Babadook
# 1420           masnegroquelanoche              Mas Negro Que La Noche
# 1421                          eye                      The Eye (2003)
# 1422                juonthegrudge                   Ju-On: The Grudge
# 1431                     deadtime                            Deadtime
# 1432                        bhoot                               Bhoot
# 1433                      inkubus                             Inkubus
# 1436                      pulse05                        Pulse (2005)
# 1437          phantomofthetheatre              Phantom of the Theatre
# 1438             deathofthevirgin                 Death of the Virgin
# ...                           ...                                 ...
# 2887                   diamondmen                         Diamond Men
# 2888                 matandocabos                       Matando Cabos
# 2890                     diamonds                            Diamonds
# 2897              thisthingofours                  This Thing of Ours
# 2898                      dukes08                           The Dukes
# 2899                         prey                            The Prey
# 2900                 lonelymaiden                   The Lonely Maiden
# 3270               privatelessons                     Private Lessons
# 3282                  springbreak                        Spring Break
# 3301                porkysrevenge          Porky's Revenge (Part III)
# 3353                       zapped                             Zapped!
# 3392                       tomboy                              Tomboy
# 3393                privateschool                      Private School
# 3398                   upthecreek                        Up the Creek
# 3401              wheretheboysare           Where the Boys Are (1984)
# 3404                     mischief                            Mischief
# 3419                   hardbodies                          Hardbodies
# 3448           lastamericanvirgin            The Last American Virgin
# 3458                studentbodies                      Student Bodies
# 3462               makingthegrade                    Making the Grade
# 3463                    missmarch                          Miss March
# 3468                    joysticks                           Joysticks
# 3480                     homework                            Homework
# 3481                     hotmoves                           Hot Moves
# 3484                   meatballs3                       Meatballs III
# 3488                   screwballs                          Screwballs
# 3498                  gettingiton                       Getting It On
# 3511                  hardbodies2                        Hardbodies 2
# 3513                  barelylegal                        Barely Legal
# 3514                 extrememovie                       Extreme Movie
#
#        Studio  life_theater  open_theater release_date               genre  \
# 337   WB (NL)        2762.0        2704.0   2016-06-03         summerdrama
# 640      Col.        1203.0        1203.0   1986-05-02         summerdrama
# 770        BV           NaN           NaN   1982-07-30         summerdrama
# 825     RAtt.         276.0         276.0   2015-05-15         summerdrama
# 828       PFR         344.0         344.0   2015-07-01         summerdrama
# 833       IFC           6.0           2.0   2015-06-05         summerdrama
# 844        WB           NaN           NaN   1973-12-26  supernaturalhorror
# 852      Art.        2538.0          27.0   1999-07-16  supernaturalhorror
# 911       AIP         748.0         748.0   1979-07-27  supernaturalhorror
# 1267     Par.        2931.0        2931.0   2017-02-03  supernaturalhorror
# 1280    Focus        2509.0        2451.0   2016-01-08  supernaturalhorror
# 1328     AVCO           NaN           NaN   1980-02-01  supernaturalhorror
# 1347    Orion        1548.0        1534.0   1987-06-12  supernaturalhorror
# 1370      MGM        1471.0        1471.0   1988-06-10  supernaturalhorror
# 1372     NCeV        1148.0        1139.0   1987-05-15  supernaturalhorror
# 1380    Orion        1200.0        1200.0   1982-09-24  supernaturalhorror
# 1396      PEC        1068.0          15.0   1986-12-31  supernaturalhorror
# 1416     Triu         350.0         350.0   1992-02-28  supernaturalhorror
# 1417      LGF         427.0         427.0   2015-07-24  supernaturalhorror
# 1418      ADF        1000.0        1000.0   2007-02-23  supernaturalhorror
# 1419      IFC          80.0           3.0   2014-11-28  supernaturalhorror
# 1420      LGF         178.0         178.0   2014-09-26  supernaturalhorror
# 1421     Palm          23.0          13.0   2003-06-06  supernaturalhorror
# 1422    Vita.          11.0           3.0   2004-07-23  supernaturalhorror
# 1431    Noct.          18.0          18.0   2012-05-11  supernaturalhorror
# 1432      Spk          19.0          19.0   2003-05-30  supernaturalhorror
# 1433    Scre.          16.0           NaN   2011-10-28  supernaturalhorror
# 1436    Magn.           5.0           1.0   2005-11-09  supernaturalhorror
# 1437    WGUSA          26.0          26.0   2016-05-06  supernaturalhorror
# 1438   Indic.           3.0           3.0   2012-02-10  supernaturalhorror
# ...       ...           ...           ...          ...                 ...
# 2887     Pan.          15.0           3.0   2001-09-14               caper
# 2888     Tele          82.0          82.0   2005-08-26               caper
# 2890    Mira.          27.0           2.0   1999-12-10               caper
# 2897     SmlP           7.0           4.0   2003-07-18               caper
# 2898     CAVU          11.0           4.0   2008-11-14               caper
# 2899    Cohen           5.0           5.0   2013-06-06               caper
# 2900      YFG           NaN           NaN   2009-05-29               caper
# 3270     JenF         224.0         179.0   1981-08-28       r-ratedcomedy
# 3282     Col.        1531.0        1493.0   1983-03-25       r-ratedcomedy
# 3301      Fox        1423.0        1423.0   1985-03-22       r-ratedcomedy
# 3353      Emb         777.0         200.0   1982-07-23       r-ratedcomedy
# 3392     Crwn         409.0         409.0   1985-01-25       r-ratedcomedy
# 3393     Uni.        1024.0        1024.0   1983-07-29       r-ratedcomedy
# 3398    Orion        1346.0        1346.0   1984-04-06       r-ratedcomedy
# 3401     TriS        1414.0        1414.0   1984-04-06       r-ratedcomedy
# 3404      Fox        1221.0        1221.0   1985-02-08       r-ratedcomedy
# 3419     Col.        1594.0        1538.0   1984-05-04       r-ratedcomedy
# 3448     Can.         158.0         158.0   1982-08-06       r-ratedcomedy
# 3458     Par.           NaN         628.0   1981-08-07       r-ratedcomedy
# 3462     Can.        1197.0        1197.0   1984-05-18       r-ratedcomedy
# 3463     FoxS        1742.0        1742.0   2009-03-13       r-ratedcomedy
# 3468     JenF         310.0         310.0   1983-03-04       r-ratedcomedy
# 3480     JenF         262.0         262.0   1982-08-27       r-ratedcomedy
# 3481     Card           NaN           NaN   1985-05-17       r-ratedcomedy
# 3484     MovE           NaN           NaN   1987-01-09       r-ratedcomedy
# 3488       NW         128.0          75.0   1983-04-01       r-ratedcomedy
# 3498     Comw         350.0         350.0   1983-08-19       r-ratedcomedy
# 3511     Cntl          46.0          46.0   1986-09-12       r-ratedcomedy
# 3513     Sony          20.0          20.0   2005-10-21       r-ratedcomedy
# 3514   W/Dim.           3.0           3.0   2008-12-05       r-ratedcomedy
#
#       rank_num  log_life_gross  log_open_gross  release_yr  release_wday_num  \
# 337       39.0       17.845229       16.745278        2016                 5
# 640       95.0       16.707778       15.400473        1986                 5
# 770      121.0       15.816991             NaN        1982                 5
# 825      141.0       13.960476       13.033066        2015                 5
# 828      143.0       13.819607       12.989974        2015                 3
# 833      145.0        8.842316        7.533159        2015                 5
# 844        2.0       19.266146             NaN        1973                 3
# 852        4.0       18.760996       14.228980        1999                 5
# 911       13.0       18.274869       15.875192        1979                 5
# 1267      73.0       17.140295       16.380662        2017                 5
# 1280      77.0       17.096206       16.360350        2016                 5
# 1328      90.0       16.877890             NaN        1980                 5
# 1347      96.0       16.746888       15.284014        1987                 5
# 1370     103.0       16.462712       15.284377        1988                 5
# 1372     105.0       16.421119       15.264325        1987                 5
# 1380     108.0       16.344021       15.227540        1982                 5
# 1396     112.0       15.812843       11.466201        1986                 3
# 1416     119.0       14.525010       13.867320        1992                 5
# 1417     120.0       14.394796       13.631913        2015                 5
# 1418     121.0       14.101544       13.569610        2007                 5
# 1419     122.0       13.779275       10.309186        2014                 5
# 1420     123.0       13.676321       13.199078        2014                 5
# 1421     124.0       13.146176       11.035889        2003                 5
# 1422     125.0       12.693671       10.144314        2004                 5
# 1431     128.0       11.958073       10.316921        2012                 5
# 1432     129.0       11.578470       11.002100        2003                 5
# 1433     130.0       11.309585             NaN        2011                 5
# 1436     132.0       10.847782        8.888757        2005                 3
# 1437     133.0       10.690922        9.952325        2016                 5
# 1438     134.0       10.136463        9.062768        2012                 5
# ...        ...             ...             ...         ...               ...
# 2887      97.0       12.161185        9.598931        2001                 5
# 2888      98.0       11.956803       11.234930        2005                 5
# 2890     100.0       11.389944        8.966611        1999                 5
# 2897     103.0       10.524790        8.988071        2003                 5
# 2898     104.0       10.198952        8.710620        2008                 5
# 2899     105.0        9.543880        8.680841        2013                 4
# 2900       NaN             NaN             NaN        2009                 5
# 3270      42.0       17.084281       13.870148        1981                 5
# 3282      44.0       16.996546       15.591915        1983                 5
# 3301      49.0       16.836857       15.641270        1985                 5
# 3353      57.0       16.642692       13.621377        1982                 5
# 3392      65.0       16.461685       14.360120        1985                 5
# 3393      66.0       16.458100       15.299807        1983                 5
# 3398      68.0       16.275806       14.982056        1984                 5
# 3401      70.0       16.169739       15.114363        1984                 5
# 3404      72.0       15.977963       14.778097        1985                 5
# 3419      77.0       15.778660       14.803042        1984                 5
# 3448      83.0       15.578490       13.175331        1982                 5
# 3458      87.0       15.457499       14.274294        1981                 5
# 3462      90.0       15.333128       14.381311        1984                 5
# 3463      91.0       15.329169       14.694787        2009                 5
# 3468      94.0       15.189846       14.173929        1983                 5
# 3480      99.0       14.885150       14.127789        1982                 5
# 3481     100.0       14.820795             NaN        1985                 5
# 3484     102.0       14.579688             NaN        1987                 5
# 3488     104.0       14.548943       12.254863        1983                 5
# 3498     108.0       13.790617       13.790617        1983                 5
# 3511     113.0       11.265336       11.265336        1986                 5
# 3513     115.0       10.185315        9.665611        2005                 5
# 3514       NaN             NaN             NaN        2008                 5
#
#       release_mon  release_mon2  release_mon3 genre_sd genre_cm genre_r  \
# 337             6            36           216     True    False   False
# 640             5            25           125     True    False   False
# 770             7            49           343     True    False   False
# 825             5            25           125     True    False   False
# 828             7            49           343     True    False   False
# 833             6            36           216     True    False   False
# 844            12           144          1728    False    False   False
# 852             7            49           343    False    False   False
# 911             7            49           343    False    False   False
# 1267            2             4             8    False    False   False
# 1280            1             1             1    False    False   False
# 1328            2             4             8    False    False   False
# 1347            6            36           216    False    False   False
# 1370            6            36           216    False    False   False
# 1372            5            25           125    False    False   False
# 1380            9            81           729    False    False   False
# 1396           12           144          1728    False    False   False
# 1416            2             4             8    False    False   False
# 1417            7            49           343    False    False   False
# 1418            2             4             8    False    False   False
# 1419           11           121          1331    False    False   False
# 1420            9            81           729    False    False   False
# 1421            6            36           216    False    False   False
# 1422            7            49           343    False    False   False
# 1431            5            25           125    False    False   False
# 1432            5            25           125    False    False   False
# 1433           10           100          1000    False    False   False
# 1436           11           121          1331    False    False   False
# 1437            5            25           125    False    False   False
# 1438            2             4             8    False    False   False
# ...           ...           ...           ...      ...      ...     ...
# 2887            9            81           729    False    False   False
# 2888            8            64           512    False    False   False
# 2890           12           144          1728    False    False   False
# 2897            7            49           343    False    False   False
# 2898           11           121          1331    False    False   False
# 2899            6            36           216    False    False   False
# 2900            5            25           125    False    False   False
# 3270            8            64           512    False    False    True
# 3282            3             9            27    False    False    True
# 3301            3             9            27    False    False    True
# 3353            7            49           343    False    False    True
# 3392            1             1             1    False    False    True
# 3393            7            49           343    False    False    True
# 3398            4            16            64    False    False    True
# 3401            4            16            64    False    False    True
# 3404            2             4             8    False    False    True
# 3419            5            25           125    False    False    True
# 3448            8            64           512    False    False    True
# 3458            8            64           512    False    False    True
# 3462            5            25           125    False    False    True
# 3463            3             9            27    False    False    True
# 3468            3             9            27    False    False    True
# 3480            8            64           512    False    False    True
# 3481            5            25           125    False    False    True
# 3484            1             1             1    False    False    True
# 3488            4            16            64    False    False    True
# 3498            8            64           512    False    False    True
# 3511            9            81           729    False    False    True
# 3513           10           100          1000    False    False    True
# 3514           12           144          1728    False    False    True
#
#      genre_cp  mpaa_pg13  mpaa_pg  runtime_mins  log_budget_num  \
# 337     False        1.0      0.0         110.0       16.811243
# 640     False        NaN      NaN           NaN             NaN
# 770     False        NaN      NaN           NaN             NaN
# 825     False        NaN      NaN           NaN             NaN
# 828     False        NaN      NaN           NaN             NaN
# 833     False        NaN      NaN           NaN             NaN
# 844     False        NaN      NaN           NaN             NaN
# 852     False        0.0      0.0          86.0       11.002100
# 911     False        NaN      NaN           NaN             NaN
# 1267    False        1.0      0.0         102.0       17.034386
# 1280    False        1.0      0.0          95.0       16.118096
# 1328    False        NaN      NaN           NaN             NaN
# 1347    False        NaN      NaN           NaN             NaN
# 1370    False        NaN      NaN           NaN             NaN
# 1372    False        NaN      NaN           NaN             NaN
# 1380    False        NaN      NaN           NaN             NaN
# 1396    False        NaN      NaN           NaN             NaN
# 1416    False        NaN      NaN           NaN             NaN
# 1417    False        NaN      NaN           NaN             NaN
# 1418    False        NaN      NaN           NaN             NaN
# 1419    False        NaN      NaN           NaN             NaN
# 1420    False        NaN      NaN           NaN             NaN
# 1421    False        NaN      NaN           NaN             NaN
# 1422    False        NaN      NaN           NaN             NaN
# 1431    False        NaN      NaN           NaN             NaN
# 1432    False        NaN      NaN           NaN             NaN
# 1433    False        NaN      NaN           NaN             NaN
# 1436    False        NaN      NaN           NaN             NaN
# 1437    False        NaN      NaN           NaN             NaN
# 1438    False        NaN      NaN           NaN             NaN
# ...       ...        ...      ...           ...             ...
# 2887     True        NaN      NaN           NaN             NaN
# 2888     True        NaN      NaN           NaN             NaN
# 2890     True        NaN      NaN           NaN             NaN
# 2897     True        NaN      NaN           NaN             NaN
# 2898     True        NaN      NaN           NaN             NaN
# 2899     True        NaN      NaN           NaN             NaN
# 2900     True        NaN      NaN           NaN             NaN
# 3270    False        0.0      0.0          87.0       14.845130
# 3282    False        NaN      NaN           NaN             NaN
# 3301    False        NaN      NaN           NaN             NaN
# 3353    False        NaN      NaN           NaN             NaN
# 3392    False        NaN      NaN           NaN             NaN
# 3393    False        NaN      NaN           NaN             NaN
# 3398    False        NaN      NaN           NaN             NaN
# 3401    False        NaN      NaN           NaN             NaN
# 3404    False        NaN      NaN           NaN             NaN
# 3419    False        NaN      NaN           NaN             NaN
# 3448    False        NaN      NaN           NaN             NaN
# 3458    False        NaN      NaN           NaN             NaN
# 3462    False        NaN      NaN           NaN             NaN
# 3463    False        NaN      NaN           NaN             NaN
# 3468    False        NaN      NaN           NaN             NaN
# 3480    False        NaN      NaN           NaN             NaN
# 3481    False        NaN      NaN           NaN             NaN
# 3484    False        NaN      NaN           NaN             NaN
# 3488    False        0.0      0.0          80.0       13.592367
# 3498    False        NaN      NaN           NaN             NaN
# 3511    False        NaN      NaN           NaN             NaN
# 3513    False        NaN      NaN           NaN             NaN
# 3514    False        NaN      NaN           NaN             NaN
#
#       pct_open_gross  log_life_frn_gross  log_avg_open_gross  \
# 337            0.333           18.837415            8.842749
# 640              NaN                 NaN                 NaN
# 770              NaN                 NaN                 NaN
# 825              NaN                 NaN                 NaN
# 828              NaN                 NaN                 NaN
# 833              NaN                 NaN                 NaN
# 844              NaN                 NaN                 NaN
# 852              NaN                 NaN                 NaN
# 911              NaN                 NaN                 NaN
# 1267           0.468           17.828064            8.397508
# 1280           0.479           16.214681            8.556029
# 1328             NaN                 NaN                 NaN
# 1347             NaN                 NaN                 NaN
# 1370             NaN                 NaN                 NaN
# 1372             NaN                 NaN                 NaN
# 1380             NaN                 NaN                 NaN
# 1396             NaN                 NaN                 NaN
# 1416             NaN                 NaN                 NaN
# 1417             NaN                 NaN                 NaN
# 1418           0.587           14.853113            6.661855
# 1419           0.031           16.050687            9.210540
# 1420           0.620           15.468200            8.017308
# 1421             NaN                 NaN                 NaN
# 1422           0.078           14.800965            9.045702
# 1431             NaN                 NaN                 NaN
# 1432           0.562           15.077855            8.057377
# 1433             NaN                 NaN                 NaN
# 1436             NaN                 NaN                 NaN
# 1437             NaN                 NaN                 NaN
# 1438             NaN                 NaN                 NaN
# ...              ...                 ...                 ...
# 2887             NaN                 NaN                 NaN
# 2888           0.486           15.519753            6.827629
# 2890             NaN                 NaN                 NaN
# 2897             NaN                 NaN                 NaN
# 2898             NaN                 NaN                 NaN
# 2899             NaN                 NaN                 NaN
# 2900             NaN                 NaN                 NaN
# 3270             NaN                 NaN                 NaN
# 3282             NaN                 NaN                 NaN
# 3301             NaN                 NaN                 NaN
# 3353             NaN                 NaN                 NaN
# 3392             NaN                 NaN                 NaN
# 3393             NaN                 NaN                 NaN
# 3398             NaN                 NaN                 NaN
# 3401             NaN                 NaN                 NaN
# 3404             NaN                 NaN                 NaN
# 3419             NaN                 NaN                 NaN
# 3448             NaN                 NaN                 NaN
# 3458             NaN                 NaN                 NaN
# 3462             NaN                 NaN                 NaN
# 3463           0.530           10.785373            7.232010
# 3468             NaN                 NaN                 NaN
# 3480             NaN                 NaN                 NaN
# 3481             NaN                 NaN                 NaN
# 3484             NaN                 NaN                 NaN
# 3488             NaN                 NaN                 NaN
# 3498             NaN                 NaN                 NaN
# 3511             NaN                 NaN                 NaN
# 3513           0.595           10.949543            6.669498
# 3514             NaN                 NaN                 NaN
#
#       ww_log_life_gross  pct_life_gross  n_miss_mv_cols role playerid player  \
# 337           19.152785        0.270480               0  NaN      NaN    NaN
# 640                 NaN             NaN               9  NaN      NaN    NaN
# 770                 NaN             NaN              12  NaN      NaN    NaN
# 825                 NaN             NaN               9  NaN      NaN    NaN
# 828                 NaN             NaN               9  NaN      NaN    NaN
# 833                 NaN             NaN               9  NaN      NaN    NaN
# 844                 NaN             NaN              12  NaN      NaN    NaN
# 852                 NaN             NaN               5  NaN      NaN    NaN
# 911                 NaN             NaN               9  NaN      NaN    NaN
# 1267          18.235325        0.334530               0  NaN      NaN    NaN
# 1280          17.442735        0.707138               0  NaN      NaN    NaN
# 1328                NaN             NaN              12  NaN      NaN    NaN
# 1347                NaN             NaN               9  NaN      NaN    NaN
# 1370                NaN             NaN               9  NaN      NaN    NaN
# 1372                NaN             NaN               9  NaN      NaN    NaN
# 1380                NaN             NaN               9  NaN      NaN    NaN
# 1396                NaN             NaN               9  NaN      NaN    NaN
# 1416                NaN             NaN               9  NaN      NaN    NaN
# 1417                NaN             NaN               9  NaN      NaN    NaN
# 1418          15.239481        0.320480               4  NaN      NaN    NaN
# 1419          16.148871        0.093518               4  NaN      NaN    NaN
# 1420          15.622333        0.142843               4  NaN      NaN    NaN
# 1421                NaN             NaN               9  NaN      NaN    NaN
# 1422          14.915691        0.108390               4  NaN      NaN    NaN
# 1431                NaN             NaN               9  NaN      NaN    NaN
# 1432          15.107624        0.029330               4  NaN      NaN    NaN
# 1433                NaN             NaN              11  NaN      NaN    NaN
# 1436                NaN             NaN               9  NaN      NaN    NaN
# 1437                NaN             NaN               9  NaN      NaN    NaN
# 1438                NaN             NaN               9  NaN      NaN    NaN
# ...                 ...             ...             ...  ...      ...    ...
# 2887                NaN             NaN               9  NaN      NaN    NaN
# 2888          15.547713        0.027573               4  NaN      NaN    NaN
# 2890                NaN             NaN               9  NaN      NaN    NaN
# 2897                NaN             NaN               9  NaN      NaN    NaN
# 2898                NaN             NaN               9  NaN      NaN    NaN
# 2899                NaN             NaN               9  NaN      NaN    NaN
# 2900                NaN             NaN              14  NaN      NaN    NaN
# 3270                NaN             NaN               5  NaN      NaN    NaN
# 3282                NaN             NaN               9  NaN      NaN    NaN
# 3301                NaN             NaN               9  NaN      NaN    NaN
# 3353                NaN             NaN               9  NaN      NaN    NaN
# 3392                NaN             NaN               9  NaN      NaN    NaN
# 3393                NaN             NaN               9  NaN      NaN    NaN
# 3398                NaN             NaN               9  NaN      NaN    NaN
# 3401                NaN             NaN               9  NaN      NaN    NaN
# 3404                NaN             NaN               9  NaN      NaN    NaN
# 3419                NaN             NaN               9  NaN      NaN    NaN
# 3448                NaN             NaN               9  NaN      NaN    NaN
# 3458                NaN             NaN              10  NaN      NaN    NaN
# 3462                NaN             NaN               9  NaN      NaN    NaN
# 3463          15.339745        0.989479               4  NaN      NaN    NaN
# 3468                NaN             NaN               9  NaN      NaN    NaN
# 3480                NaN             NaN               9  NaN      NaN    NaN
# 3481                NaN             NaN              12  NaN      NaN    NaN
# 3484                NaN             NaN              12  NaN      NaN    NaN
# 3488                NaN             NaN               5  NaN      NaN    NaN
# 3498                NaN             NaN               9  NaN      NaN    NaN
# 3511                NaN             NaN               9  NaN      NaN    NaN
# 3513          11.331871        0.317729               4  NaN      NaN    NaN
# 3514                NaN             NaN              12  NaN      NaN    NaN
#
#       plr_life_mv_num  plr_open_mv_num  plr_log_life_gross  plr_log_avg_gross  \
# 337               NaN              NaN                 NaN                NaN
# 640               NaN              NaN                 NaN                NaN
# 770               NaN              NaN                 NaN                NaN
# 825               NaN              NaN                 NaN                NaN
# 828               NaN              NaN                 NaN                NaN
# 833               NaN              NaN                 NaN                NaN
# 844               NaN              NaN                 NaN                NaN
# 852               NaN              NaN                 NaN                NaN
# 911               NaN              NaN                 NaN                NaN
# 1267              NaN              NaN                 NaN                NaN
# 1280              NaN              NaN                 NaN                NaN
# 1328              NaN              NaN                 NaN                NaN
# 1347              NaN              NaN                 NaN                NaN
# 1370              NaN              NaN                 NaN                NaN
# 1372              NaN              NaN                 NaN                NaN
# 1380              NaN              NaN                 NaN                NaN
# 1396              NaN              NaN                 NaN                NaN
# 1416              NaN              NaN                 NaN                NaN
# 1417              NaN              NaN                 NaN                NaN
# 1418              NaN              NaN                 NaN                NaN
# 1419              NaN              NaN                 NaN                NaN
# 1420              NaN              NaN                 NaN                NaN
# 1421              NaN              NaN                 NaN                NaN
# 1422              NaN              NaN                 NaN                NaN
# 1431              NaN              NaN                 NaN                NaN
# 1432              NaN              NaN                 NaN                NaN
# 1433              NaN              NaN                 NaN                NaN
# 1436              NaN              NaN                 NaN                NaN
# 1437              NaN              NaN                 NaN                NaN
# 1438              NaN              NaN                 NaN                NaN
# ...               ...              ...                 ...                ...
# 2887              NaN              NaN                 NaN                NaN
# 2888              NaN              NaN                 NaN                NaN
# 2890              NaN              NaN                 NaN                NaN
# 2897              NaN              NaN                 NaN                NaN
# 2898              NaN              NaN                 NaN                NaN
# 2899              NaN              NaN                 NaN                NaN
# 2900              NaN              NaN                 NaN                NaN
# 3270              NaN              NaN                 NaN                NaN
# 3282              NaN              NaN                 NaN                NaN
# 3301              NaN              NaN                 NaN                NaN
# 3353              NaN              NaN                 NaN                NaN
# 3392              NaN              NaN                 NaN                NaN
# 3393              NaN              NaN                 NaN                NaN
# 3398              NaN              NaN                 NaN                NaN
# 3401              NaN              NaN                 NaN                NaN
# 3404              NaN              NaN                 NaN                NaN
# 3419              NaN              NaN                 NaN                NaN
# 3448              NaN              NaN                 NaN                NaN
# 3458              NaN              NaN                 NaN                NaN
# 3462              NaN              NaN                 NaN                NaN
# 3463              NaN              NaN                 NaN                NaN
# 3468              NaN              NaN                 NaN                NaN
# 3480              NaN              NaN                 NaN                NaN
# 3481              NaN              NaN                 NaN                NaN
# 3484              NaN              NaN                 NaN                NaN
# 3488              NaN              NaN                 NaN                NaN
# 3498              NaN              NaN                 NaN                NaN
# 3511              NaN              NaN                 NaN                NaN
# 3513              NaN              NaN                 NaN                NaN
# 3514              NaN              NaN                 NaN                NaN
#
#       plr_log_avg_open_gross  life_theater_1yr  log_life_gross_1yr  \
# 337                      NaN               NaN                 NaN
# 640                      NaN               NaN                 NaN
# 770                      NaN               NaN                 NaN
# 825                      NaN               NaN                 NaN
# 828                      NaN               NaN                 NaN
# 833                      NaN               NaN                 NaN
# 844                      NaN               NaN                 NaN
# 852                      NaN               NaN                 NaN
# 911                      NaN               NaN                 NaN
# 1267                     NaN               NaN                 NaN
# 1280                     NaN               NaN                 NaN
# 1328                     NaN               NaN                 NaN
# 1347                     NaN               NaN                 NaN
# 1370                     NaN               NaN                 NaN
# 1372                     NaN               NaN                 NaN
# 1380                     NaN               NaN                 NaN
# 1396                     NaN               NaN                 NaN
# 1416                     NaN               NaN                 NaN
# 1417                     NaN               NaN                 NaN
# 1418                     NaN               NaN                 NaN
# 1419                     NaN               NaN                 NaN
# 1420                     NaN               NaN                 NaN
# 1421                     NaN               NaN                 NaN
# 1422                     NaN               NaN                 NaN
# 1431                     NaN               NaN                 NaN
# 1432                     NaN               NaN                 NaN
# 1433                     NaN               NaN                 NaN
# 1436                     NaN               NaN                 NaN
# 1437                     NaN               NaN                 NaN
# 1438                     NaN               NaN                 NaN
# ...                      ...               ...                 ...
# 2887                     NaN               NaN                 NaN
# 2888                     NaN               NaN                 NaN
# 2890                     NaN               NaN                 NaN
# 2897                     NaN               NaN                 NaN
# 2898                     NaN               NaN                 NaN
# 2899                     NaN               NaN                 NaN
# 2900                     NaN               NaN                 NaN
# 3270                     NaN               NaN                 NaN
# 3282                     NaN               NaN                 NaN
# 3301                     NaN               NaN                 NaN
# 3353                     NaN               NaN                 NaN
# 3392                     NaN               NaN                 NaN
# 3393                     NaN               NaN                 NaN
# 3398                     NaN               NaN                 NaN
# 3401                     NaN               NaN                 NaN
# 3404                     NaN               NaN                 NaN
# 3419                     NaN               NaN                 NaN
# 3448                     NaN               NaN                 NaN
# 3458                     NaN               NaN                 NaN
# 3462                     NaN               NaN                 NaN
# 3463                     NaN               NaN                 NaN
# 3468                     NaN               NaN                 NaN
# 3480                     NaN               NaN                 NaN
# 3481                     NaN               NaN                 NaN
# 3484                     NaN               NaN                 NaN
# 3488                     NaN               NaN                 NaN
# 3498                     NaN               NaN                 NaN
# 3511                     NaN               NaN                 NaN
# 3513                     NaN               NaN                 NaN
# 3514                     NaN               NaN                 NaN
#
#       log_open_gross_1yr  open_theater_1yr  rank_num_1yr  life_theater_3yr  \
# 337                  NaN               NaN           NaN               NaN
# 640                  NaN               NaN           NaN               NaN
# 770                  NaN               NaN           NaN               NaN
# 825                  NaN               NaN           NaN               NaN
# 828                  NaN               NaN           NaN               NaN
# 833                  NaN               NaN           NaN               NaN
# 844                  NaN               NaN           NaN               NaN
# 852                  NaN               NaN           NaN               NaN
# 911                  NaN               NaN           NaN               NaN
# 1267                 NaN               NaN           NaN               NaN
# 1280                 NaN               NaN           NaN               NaN
# 1328                 NaN               NaN           NaN               NaN
# 1347                 NaN               NaN           NaN               NaN
# 1370                 NaN               NaN           NaN               NaN
# 1372                 NaN               NaN           NaN               NaN
# 1380                 NaN               NaN           NaN               NaN
# 1396                 NaN               NaN           NaN               NaN
# 1416                 NaN               NaN           NaN               NaN
# 1417                 NaN               NaN           NaN               NaN
# 1418                 NaN               NaN           NaN               NaN
# 1419                 NaN               NaN           NaN               NaN
# 1420                 NaN               NaN           NaN               NaN
# 1421                 NaN               NaN           NaN               NaN
# 1422                 NaN               NaN           NaN               NaN
# 1431                 NaN               NaN           NaN               NaN
# 1432                 NaN               NaN           NaN               NaN
# 1433                 NaN               NaN           NaN               NaN
# 1436                 NaN               NaN           NaN               NaN
# 1437                 NaN               NaN           NaN               NaN
# 1438                 NaN               NaN           NaN               NaN
# ...                  ...               ...           ...               ...
# 2887                 NaN               NaN           NaN               NaN
# 2888                 NaN               NaN           NaN               NaN
# 2890                 NaN               NaN           NaN               NaN
# 2897                 NaN               NaN           NaN               NaN
# 2898                 NaN               NaN           NaN               NaN
# 2899                 NaN               NaN           NaN               NaN
# 2900                 NaN               NaN           NaN               NaN
# 3270                 NaN               NaN           NaN               NaN
# 3282                 NaN               NaN           NaN               NaN
# 3301                 NaN               NaN           NaN               NaN
# 3353                 NaN               NaN           NaN               NaN
# 3392                 NaN               NaN           NaN               NaN
# 3393                 NaN               NaN           NaN               NaN
# 3398                 NaN               NaN           NaN               NaN
# 3401                 NaN               NaN           NaN               NaN
# 3404                 NaN               NaN           NaN               NaN
# 3419                 NaN               NaN           NaN               NaN
# 3448                 NaN               NaN           NaN               NaN
# 3458                 NaN               NaN           NaN               NaN
# 3462                 NaN               NaN           NaN               NaN
# 3463                 NaN               NaN           NaN               NaN
# 3468                 NaN               NaN           NaN               NaN
# 3480                 NaN               NaN           NaN               NaN
# 3481                 NaN               NaN           NaN               NaN
# 3484                 NaN               NaN           NaN               NaN
# 3488                 NaN               NaN           NaN               NaN
# 3498                 NaN               NaN           NaN               NaN
# 3511                 NaN               NaN           NaN               NaN
# 3513                 NaN               NaN           NaN               NaN
# 3514                 NaN               NaN           NaN               NaN
#
#       log_life_gross_3yr  log_open_gross_3yr  open_theater_3yr  rank_num_3yr  \
# 337                  NaN                 NaN               NaN           NaN
# 640                  NaN                 NaN               NaN           NaN
# 770                  NaN                 NaN               NaN           NaN
# 825                  NaN                 NaN               NaN           NaN
# 828                  NaN                 NaN               NaN           NaN
# 833                  NaN                 NaN               NaN           NaN
# 844                  NaN                 NaN               NaN           NaN
# 852                  NaN                 NaN               NaN           NaN
# 911                  NaN                 NaN               NaN           NaN
# 1267                 NaN                 NaN               NaN           NaN
# 1280                 NaN                 NaN               NaN           NaN
# 1328                 NaN                 NaN               NaN           NaN
# 1347                 NaN                 NaN               NaN           NaN
# 1370                 NaN                 NaN               NaN           NaN
# 1372                 NaN                 NaN               NaN           NaN
# 1380                 NaN                 NaN               NaN           NaN
# 1396                 NaN                 NaN               NaN           NaN
# 1416                 NaN                 NaN               NaN           NaN
# 1417                 NaN                 NaN               NaN           NaN
# 1418                 NaN                 NaN               NaN           NaN
# ...
# 3480               NaN           NaN                 NaN
# 3481               NaN           NaN                 NaN
# 3484               NaN           NaN                 NaN
# 3488               NaN           NaN                 NaN
# 3498               NaN           NaN                 NaN
# 3511               NaN           NaN                 NaN
# 3513               NaN           NaN                 NaN
# 3514               NaN           NaN                 NaN
#
#       log_life_gross_allyr  log_open_gross_allyr  open_theater_allyr  \
# 337                    NaN                   NaN                 NaN
# 640                    NaN                   NaN                 NaN
# 770                    NaN                   NaN                 NaN
# 825                    NaN                   NaN                 NaN
# 828                    NaN                   NaN                 NaN
# 833                    NaN                   NaN                 NaN
# 844                    NaN                   NaN                 NaN
# 852                    NaN                   NaN                 NaN
# 911                    NaN                   NaN                 NaN
# 1267                   NaN                   NaN                 NaN
# 1280                   NaN                   NaN                 NaN
# 1328                   NaN                   NaN                 NaN
# 1347                   NaN                   NaN                 NaN
# 1370                   NaN                   NaN                 NaN
# 1372                   NaN                   NaN                 NaN
# 1380                   NaN                   NaN                 NaN
# 1396                   NaN                   NaN                 NaN
# 1416                   NaN                   NaN                 NaN
# 1417                   NaN                   NaN                 NaN
# 1418                   NaN                   NaN                 NaN
# 1419                   NaN                   NaN                 NaN
# 1420                   NaN                   NaN                 NaN
# 1421                   NaN                   NaN                 NaN
# 1422                   NaN                   NaN                 NaN
# 1431                   NaN                   NaN                 NaN
# 1432                   NaN                   NaN                 NaN
# 1433                   NaN                   NaN                 NaN
# 1436                   NaN                   NaN                 NaN
# 1437                   NaN                   NaN                 NaN
# 1438                   NaN                   NaN                 NaN
# ...                    ...                   ...                 ...
# 2887                   NaN                   NaN                 NaN
# 2888                   NaN                   NaN                 NaN
# 2890                   NaN                   NaN                 NaN
# 2897                   NaN                   NaN                 NaN
# 2898                   NaN                   NaN                 NaN
# 2899                   NaN                   NaN                 NaN
# 2900                   NaN                   NaN                 NaN
# 3270                   NaN                   NaN                 NaN
# 3282                   NaN                   NaN                 NaN
# 3301                   NaN                   NaN                 NaN
# 3353                   NaN                   NaN                 NaN
# 3392                   NaN                   NaN                 NaN
# 3393                   NaN                   NaN                 NaN
# 3398                   NaN                   NaN                 NaN
# 3401                   NaN                   NaN                 NaN
# 3404                   NaN                   NaN                 NaN
# 3419                   NaN                   NaN                 NaN
# 3448                   NaN                   NaN                 NaN
# 3458                   NaN                   NaN                 NaN
# 3462                   NaN                   NaN                 NaN
# 3463                   NaN                   NaN                 NaN
# 3468                   NaN                   NaN                 NaN
# 3480                   NaN                   NaN                 NaN
# 3481                   NaN                   NaN                 NaN
# 3484                   NaN                   NaN                 NaN
# 3488                   NaN                   NaN                 NaN
# 3498                   NaN                   NaN                 NaN
# 3511                   NaN                   NaN                 NaN
# 3513                   NaN                   NaN                 NaN
# 3514                   NaN                   NaN                 NaN
#
#       rank_num_allyr  log_life_gross_diff31  log_open_gross_diff31  \
# 337              NaN                    NaN                    NaN
# 640              NaN                    NaN                    NaN
# 770              NaN                    NaN                    NaN
# 825              NaN                    NaN                    NaN
# 828              NaN                    NaN                    NaN
# 833              NaN                    NaN                    NaN
# 844              NaN                    NaN                    NaN
# 852              NaN                    NaN                    NaN
# 911              NaN                    NaN                    NaN
# 1267             NaN                    NaN                    NaN
# 1280             NaN                    NaN                    NaN
# 1328             NaN                    NaN                    NaN
# 1347             NaN                    NaN                    NaN
# 1370             NaN                    NaN                    NaN
# 1372             NaN                    NaN                    NaN
# 1380             NaN                    NaN                    NaN
# 1396             NaN                    NaN                    NaN
# 1416             NaN                    NaN                    NaN
# 1417             NaN                    NaN                    NaN
# 1418             NaN                    NaN                    NaN
# 1419             NaN                    NaN                    NaN
# 1420             NaN                    NaN                    NaN
# 1421             NaN                    NaN                    NaN
# 1422             NaN                    NaN                    NaN
# 1431             NaN                    NaN                    NaN
# 1432             NaN                    NaN                    NaN
# 1433             NaN                    NaN                    NaN
# 1436             NaN                    NaN                    NaN
# 1437             NaN                    NaN                    NaN
# 1438             NaN                    NaN                    NaN
# ...              ...                    ...                    ...
# 2887             NaN                    NaN                    NaN
# 2888             NaN                    NaN                    NaN
# 2890             NaN                    NaN                    NaN
# 2897             NaN                    NaN                    NaN
# 2898             NaN                    NaN                    NaN
# 2899             NaN                    NaN                    NaN
# 2900             NaN                    NaN                    NaN
# 3270             NaN                    NaN                    NaN
# 3282             NaN                    NaN                    NaN
# 3301             NaN                    NaN                    NaN
# 3353             NaN                    NaN                    NaN
# 3392             NaN                    NaN                    NaN
# 3393             NaN                    NaN                    NaN
# 3398             NaN                    NaN                    NaN
# 3401             NaN                    NaN                    NaN
# 3404             NaN                    NaN                    NaN
# 3419             NaN                    NaN                    NaN
# 3448             NaN                    NaN                    NaN
# 3458             NaN                    NaN                    NaN
# 3462             NaN                    NaN                    NaN
# 3463             NaN                    NaN                    NaN
# 3468             NaN                    NaN                    NaN
# 3480             NaN                    NaN                    NaN
# 3481             NaN                    NaN                    NaN
# 3484             NaN                    NaN                    NaN
# 3488             NaN                    NaN                    NaN
# 3498             NaN                    NaN                    NaN
# 3511             NaN                    NaN                    NaN
# 3513             NaN                    NaN                    NaN
# 3514             NaN                    NaN                    NaN
#
#       log_life_gross_diff53  log_open_gross_diff53  studio_mv_ct  rank_stu  \
# 337                     NaN                    NaN         293.0      67.0
# 640                     NaN                    NaN         431.0      73.0
# 770                     NaN                    NaN        1992.0      83.0
# 825                     NaN                    NaN         165.0      57.0
# 828                     NaN                    NaN           3.0       3.0
# 833                     NaN                    NaN         325.0      69.0
# 844                     NaN                    NaN        3190.0      86.0
# 852                     NaN                    NaN          76.0      44.0
# 911                     NaN                    NaN          13.0      13.0
# 1267                    NaN                    NaN        1929.0      82.0
# 1280                    NaN                    NaN         442.0      74.0
# 1328                    NaN                    NaN          14.0      14.0
# 1347                    NaN                    NaN         220.0      63.0
# 1370                    NaN                    NaN         699.0      78.0
# 1372                    NaN                    NaN          10.0      10.0
# 1380                    NaN                    NaN         220.0      63.0
# 1396                    NaN                    NaN           6.0       6.0
# 1416                    NaN                    NaN          29.0      27.0
# 1417                    NaN                    NaN         479.0      75.0
# 1418                    NaN                    NaN           8.0       8.0
# 1419                    NaN                    NaN         325.0      69.0
# 1420                    NaN                    NaN         479.0      75.0
# 1421                    NaN                    NaN           9.0       9.0
# 1422                    NaN                    NaN           6.0       6.0
# 1431                    NaN                    NaN           NaN       NaN
# 1432                    NaN                    NaN           NaN       NaN
# 1433                    NaN                    NaN          40.0      33.0
# 1436                    NaN                    NaN         236.0      64.0
# 1437                    NaN                    NaN          10.0      10.0
# 1438                    NaN                    NaN           9.0       9.0
# ...                     ...                    ...           ...       ...
# 2887                    NaN                    NaN           2.0       2.0
# 2888                    NaN                    NaN           NaN       NaN
# 2890                    NaN                    NaN         987.0      80.0
# 2897                    NaN                    NaN           2.0       2.0
# 2898                    NaN                    NaN           NaN       NaN
# 2899                    NaN                    NaN           9.0       9.0
# 2900                    NaN                    NaN          56.0      36.0
# 3270                    NaN                    NaN           1.0       1.0
# 3282                    NaN                    NaN         431.0      73.0
# 3301                    NaN                    NaN        2116.0      84.0
# 3353                    NaN                    NaN          25.0      24.0
# 3392                    NaN                    NaN           2.0       2.0
# 3393                    NaN                    NaN        2600.0      85.0
# 3398                    NaN                    NaN         220.0      63.0
# 3401                    NaN                    NaN         348.0      70.0
# 3404                    NaN                    NaN        2116.0      84.0
# 3419                    NaN                    NaN         431.0      73.0
# 3448                    NaN                    NaN          33.0      29.0
# 3458                    NaN                    NaN        1929.0      82.0
# 3462                    NaN                    NaN          33.0      29.0
# 3463                    NaN                    NaN         504.0      77.0
# 3468                    NaN                    NaN           1.0       1.0
# 3480                    NaN                    NaN           1.0       1.0
# 3481                    NaN                    NaN           NaN       NaN
# 3484                    NaN                    NaN           3.0       3.0
# 3488                    NaN                    NaN          42.0      34.0
# 3498                    NaN                    NaN           1.0       1.0
# 3511                    NaN                    NaN           1.0       1.0
# 3513                    NaN                    NaN        1726.0      81.0
# 3514                    NaN                    NaN          85.0      45.0
#
#       rank_stu2  rank_stu3
# 337      4489.0   300763.0
# 640      5329.0   389017.0
# 770      6889.0   571787.0
# 825      3249.0   185193.0
# 828         9.0       27.0
# 833      4761.0   328509.0
# 844      7396.0   636056.0
# 852      1936.0    85184.0
# 911       169.0     2197.0
# 1267     6724.0   551368.0
# 1280     5476.0   405224.0
# 1328      196.0     2744.0
# 1347     3969.0   250047.0
# 1370     6084.0   474552.0
# 1372      100.0     1000.0
# 1380     3969.0   250047.0
# 1396       36.0      216.0
# 1416      729.0    19683.0
# 1417     5625.0   421875.0
# 1418       64.0      512.0
# 1419     4761.0   328509.0
# 1420     5625.0   421875.0
# 1421       81.0      729.0
# 1422       36.0      216.0
# 1431        NaN        NaN
# 1432        NaN        NaN
# 1433     1089.0    35937.0
# 1436     4096.0   262144.0
# 1437      100.0     1000.0
# 1438       81.0      729.0
# ...         ...        ...
# 2887        4.0        8.0
# 2888        NaN        NaN
# 2890     6400.0   512000.0
# 2897        4.0        8.0
# 2898        NaN        NaN
# 2899       81.0      729.0
# 2900     1296.0    46656.0
# 3270        1.0        1.0
# 3282     5329.0   389017.0
# 3301     7056.0   592704.0
# 3353      576.0    13824.0
# 3392        4.0        8.0
# 3393     7225.0   614125.0
# 3398     3969.0   250047.0
# 3401     4900.0   343000.0
# 3404     7056.0   592704.0
# 3419     5329.0   389017.0
# 3448      841.0    24389.0
# 3458     6724.0   551368.0
# 3462      841.0    24389.0
# 3463     5929.0   456533.0
# 3468        1.0        1.0
# 3480        1.0        1.0
# 3481        NaN        NaN
# 3484        9.0       27.0
# 3488     1156.0    39304.0
# 3498        1.0        1.0
# 3511        1.0        1.0
# 3513     6561.0   531441.0
# 3514     2025.0    91125.0
#
# [108 rows x 65 columns]

# %%
cond = (pd.isnull(movie_player['role'])) | (pd.isnull(movie_player['playerid']))
a = movie_player.loc[~cond, ['movieid', 'role']]
a = a.drop_duplicates()
#a = pd.pivot_table(a, index = 'movieid', columns = 'role', values = 'playerid')
a
# Out:
#                  movieid             role
# 0            forrestgump         Director
# 1            forrestgump           Writer
# 2            forrestgump            Actor
# 5            forrestgump         Producer
# 6            forrestgump  Cinematographer
# 7            forrestgump         Composer
# 8      savingprivateryan         Director
# 9      savingprivateryan            Actor
# 16     savingprivateryan         Producer
# 20     savingprivateryan         Composer
# 21           pearlharbor         Director
# 22           pearlharbor           Writer
# 23           pearlharbor            Actor
# 31           pearlharbor         Producer
# 34           pearlharbor         Composer
# 36             gladiator         Director
# 37             gladiator           Writer
# 40             gladiator            Actor
# 42             gladiator         Producer
# 43             gladiator         Composer
# 45          perfectstorm         Director
# 46          perfectstorm            Actor
# 50          perfectstorm         Producer
# 51          perfectstorm         Composer
# 52              apollo13         Director
# 53              apollo13            Actor
# 57              apollo13         Producer
# 59              apollo13         Composer
# 60              help2011         Director
# 61              help2011           Writer
# ...                  ...              ...
# 3467     detroitrockcity  Cinematographer
# 3469            todolist            Actor
# 3474            todolist         Producer
# 3475  fraternityvacation            Actor
# 3476              clerks         Director
# 3477              clerks           Writer
# 3478              clerks            Actor
# 3479          jawbreaker  Cinematographer
# 3482   butimacheerleader            Actor
# 3485            mallrats         Director
# 3486            mallrats           Writer
# 3487            mallrats            Actor
# 3489       kingsofsummer         Director
# 3490       kingsofsummer         Producer
# 3491             losinit         Director
# 3492             losinit            Actor
# 3494            heathers         Director
# 3495            heathers           Writer
# 3496            heathers            Actor
# 3497            heathers         Producer
# 3499        virginityhit         Producer
# 3502           somegirls         Director
# 3503           somegirls            Actor
# 3504           somegirls         Composer
# 3505       privateresort            Actor
# 3506      goingalltheway         Director
# 3507      goingalltheway            Actor
# 3509      goingalltheway         Producer
# 3510      goingalltheway         Composer
# 3512        inbetweeners            Actor
#
# [1744 rows x 2 columns]

# %%
def lala(df):
    return " ".join(list(df['role']))
a = pd.DataFrame(a.groupby('movieid').apply(lala))

# %%
a.columns = ['a']

# %%
a.loc[a['a'] == "Composer"]
# Out:
#                           a
# movieid
# americananthem     Composer
# blairwitch2        Composer
# ghostinthemachine  Composer
# heavenhelpus       Composer
# omen3              Composer

# %%
pd.DataFrame(movie_wide.loc['americananthem'])
# Out:
#                                    americananthem
# log_life_gross                            15.3936
# life_theater                                  900
# log_open_gross                            14.4404
# open_theater                                  900
# n_miss_mv_cols                                  9
# rank_num                                      134
# release_yr                                   1986
# release_mon                                     6
# release_mon2                                   36
# release_mon3                                  216
# release_wday_num                                5
# genre_sd                                     True
# genre_cm                                    False
# genre_r                                     False
# genre_cp                                    False
# mpaa_pg13                                       0
# mpaa_pg                                         0
# runtime_mins                                  129
# log_budget_num                            14.5087
# log_life_frn_gross                        11.1542
# log_avg_open_gross                        6.94601
# pct_open_gross                              0.252
# ww_log_life_gross                         14.9918
# pct_life_gross                           0.526724
# studio_mv_ct                                  431
# rank_stu                                       73
# rank_stu2                                    5329
# rank_stu3                                  389017
# plr_life_mv_num_Actor_0.0                      32
# plr_life_mv_num_Actor_1.0                      28
# ...                                           ...
# open_theater_allyr_Actor_1.0              1183.75
# open_theater_allyr_Director_0.0           658.068
# open_theater_allyr_Producer_0.0           1373.59
# open_theater_allyr_Writer_0.0             667.842
# rank_num_allyr_Actor_0.0                  18.5556
# rank_num_allyr_Actor_1.0                  16.8889
# rank_num_allyr_Director_0.0                     6
# rank_num_allyr_Producer_0.0                13.913
# rank_num_allyr_Writer_0.0                       6
# log_life_gross_diff31_Actor_0.0                 0
# log_life_gross_diff31_Actor_1.0                 0
# log_life_gross_diff31_Director_0.0              0
# log_life_gross_diff31_Producer_0.0              0
# log_life_gross_diff31_Writer_0.0                0
# log_open_gross_diff31_Actor_0.0                 0
# log_open_gross_diff31_Actor_1.0                 0
# log_open_gross_diff31_Director_0.0              0
# log_open_gross_diff31_Producer_0.0              0
# log_open_gross_diff31_Writer_0.0                0
# log_life_gross_diff53_Actor_0.0                 0
# log_life_gross_diff53_Actor_1.0                 0
# log_life_gross_diff53_Director_0.0              0
# log_life_gross_diff53_Producer_0.0              0
# log_life_gross_diff53_Writer_0.0                0
# log_open_gross_diff53_Actor_0.0                 0
# log_open_gross_diff53_Actor_1.0                 0
# log_open_gross_diff53_Director_0.0              0
# log_open_gross_diff53_Producer_0.0              0
# log_open_gross_diff53_Writer_0.0                0
# n_plrs                                          1
#
# [174 rows x 1 columns]

# %% [markdown]
# # pickle

# %%
with open('cleaned_data.pkl', 'wb') as picklefile:
    pickle.dump(movie_wide, picklefile)
